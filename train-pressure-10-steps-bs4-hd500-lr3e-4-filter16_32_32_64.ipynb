# %%
import numpy as np
import h5py
import unet_uae_filter_16_32_32_64 as vae_util
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from keras import backend as K
from keras import layers
from keras.models import Model
from keras.optimizers import Adam
import tensorflow as tf 
# tf.config.gpu.set_per_process_memory_fraction(0.75)
# tf.config.gpu.set_per_process_memory_growth(True)
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.9
K.tensorflow_backend.set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %%
def load_data(data_path, array_name_list):
    hf_r = h5py.File(data_path, 'r')
    result = []
    for name in array_name_list:
        result.append(np.array(hf_r.get(name)))
    hf_r.close()
    return result

# %%
data_dir = './data'
# load training data
data_path = os.path.join(data_dir, 'channel_40x40x20_21tsteps_2923_satifying_cases.h5')
p_t, logk = load_data(data_path, ['pressure', 'logk'])
# sat_t = np.delete(sat_t, 1251, axis = 0) # index 1251 should be removed as an outlier
# logk = np.delete(logk, 1251, axis = 0)
# load eval data
print('p_t shape is ', p_t.shape)
print('logk shape is ', logk.shape)
# Out:
# p_t shape is  (2923, 20, 40, 40, 21)
# logk shape is  (2923, 20, 40, 40, 1)

# %%
print('p_t max is ', np.max(p_t))
print('p_t min is ', np.min(p_t))
# Out:
# p_t max is  333.1432647429199
# p_t min is  308.82531884981375

# %%
depth = 10
nr = logk.shape[0]
train_nr = 2500
test_nr = 50

# %%
p_t_mean = np.mean(p_t[:train_nr, ...], axis = 0, keepdims = True)
p_t = p_t - p_t_mean
print('max p is ', np.max(p_t[:train_nr, ...]), ', min p is ', np.min(p_t[:train_nr, ...]))
max_p = np.max(p_t[:train_nr, ...], axis=(0,1,2,3), keepdims = True)
min_p = np.min(p_t[:train_nr, ...], axis=(0,1,2,3), keepdims = True)
# Out:
# max p is  10.287530207856491 , min p is  -10.395436262199155

# %%
epsilon = 1e-6
p_t = (p_t - min_p)/(max_p - min_p + 1e-6)

# %%
print('max p is ', np.max(p_t), ', min p is ', np.min(p_t))
print('max p train is ', np.max(p_t[:train_nr, ...]), ', min p train is ', np.min(p_t[:train_nr, ...]))
print('max p validation is ', np.max(p_t[test_nr:, ...]), ', min p validation is ', np.min(p_t[test_nr:, ...]))
# Out:
# max p is  0.999999951092884 , min p is  -0.016009034547514525
# max p train is  0.999999951092884 , min p train is  0.0
# max p validation is  0.999999951092884 , min p validation is  -0.016009034547514525

# %%
step_index = [1, 2, 3, 6, 8, 10, 12, 14, 17, 20]
train_x = np.concatenate([logk[:train_nr, ...], p_t[:train_nr,:, :, :, [0]]], axis = -1)
train_y = p_t[:train_nr, :, :, :, step_index]

test_x = np.concatenate([logk[nr-test_nr:, ...],  p_t[nr-test_nr:, :, :, :, [0]]], axis = -1)
test_y = p_t[nr-test_nr:,:, :, :, step_index]

train_y = train_y.transpose(0, 4, 1, 2, 3)
train_y = train_y[:, :, :, :, :, None]
test_y = test_y.transpose(0, 4, 1, 2, 3)
test_y = test_y[:, :, :, :, :, None]
print('train_x shape is ', train_x.shape)
print('train_y shape is ', train_y.shape)
print('test_x shape is ', test_x.shape)
print('test_y shape is ', test_y.shape)
# Out:
# train_x shape is  (2500, 20, 40, 40, 2)
# train_y shape is  (2500, 10, 20, 40, 40, 1)
# test_x shape is  (50, 20, 40, 40, 2)
# test_y shape is  (50, 10, 20, 40, 40, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.set_cmap('jet')
ind_case = [0, 10, 20, 30, 40, 50]
plt.figure(figsize=(50,10))
for i, k in enumerate(ind_case):
    plt.subplot(2, 3, i+1)
    plt.imshow(train_x[k, 0, :, :, 0])
    plt.colorbar(fraction=0.046)
    plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(50,10))
for i, k in enumerate(ind_case):
    plt.subplot(2, 3, i+1)
    plt.imshow(train_x[k, 0, :, :, 1])
    plt.colorbar(fraction=0.046)
    plt.tight_layout()
plt.show()

# %%
for i, k in enumerate(ind_case):
    plt.figure(figsize=(50,50))
    for i_tstep in range(depth):
        plt.subplot(1, depth, i_tstep+1)
        plt.imshow(train_y[k, i_tstep, 0, :, :, 0])
        plt.colorbar(fraction=0.046)
        plt.tight_layout()
plt.show()

# %%
input_shape=(20, 40, 40, 2)
vae_model,_ = vae_util.create_vae(input_shape, depth)
vae_model.summary(line_length=150)
# Out:
# WARNING:tensorflow:From /data3/Astro/global/miniconda3/envs/cuda10.1-tf/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /data3/Astro/global/miniconda3/envs/cuda10.1-tf/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /data3/Astro/global/miniconda3/envs/cuda10.1-tf/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /data3/Astro/global/miniconda3/envs/cuda10.1-tf/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# image (InputLayer)                               (None, 20, 40, 40, 2)            0
# ______________________________________________________________________________________________________________________________________________________
# conv3d_1 (Conv3D)                                (None, 10, 20, 20, 16)           880               image[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_1 (BatchNormalization)       (None, 10, 20, 20, 16)           64                conv3d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_1 (Activation)                        (None, 10, 20, 20, 16)           0                 batch_normalization_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_2 (Conv3D)                                (None, 10, 20, 20, 32)           13856             activation_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_2 (BatchNormalization)       (None, 10, 20, 20, 32)           128               conv3d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_2 (Activation)                        (None, 10, 20, 20, 32)           0                 batch_normalization_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_3 (Conv3D)                                (None, 5, 10, 10, 32)            27680             activation_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_3 (BatchNormalization)       (None, 5, 10, 10, 32)            128               conv3d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_3 (Activation)                        (None, 5, 10, 10, 32)            0                 batch_normalization_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_4 (Conv3D)                                (None, 5, 10, 10, 64)            55360             activation_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_4 (BatchNormalization)       (None, 5, 10, 10, 64)            256               conv3d_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_4 (Activation)                        (None, 5, 10, 10, 64)            0                 batch_normalization_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# repeat_conv_5 (RepeatConv)                       (None, 10, 5, 10, 10, 64)        0                 activation_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv_lst_m3d_1 (ConvLSTM3D)                      (None, 10, 5, 10, 10, 64)        884992            repeat_conv_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_1 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        110656            conv_lst_m3d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_2 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        256               time_distributed_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_3 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        0                 time_distributed_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_4 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        110656            time_distributed_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_5 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        256               time_distributed_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_3 (Add)                                      (None, 10, 5, 10, 10, 64)        0                 conv_lst_m3d_1[0][0]
#                                                                                                     time_distributed_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_6 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        110656            add_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_7 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        256               time_distributed_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_8 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        0                 time_distributed_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_9 (TimeDistributed)             (None, 10, 5, 10, 10, 64)        110656            time_distributed_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_10 (TimeDistributed)            (None, 10, 5, 10, 10, 64)        256               time_distributed_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# repeat_conv_4 (RepeatConv)                       (None, 10, 5, 10, 10, 64)        0                 activation_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_4 (Add)                                      (None, 10, 5, 10, 10, 64)        0                 add_3[0][0]
#                                                                                                     time_distributed_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_1 (Concatenate)                      (None, 10, 5, 10, 10, 128)       0                 repeat_conv_4[0][0]
#                                                                                                     add_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_11 (TimeDistributed)            (None, 10, 5, 10, 10, 128)       0                 concatenate_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_12 (TimeDistributed)            (None, 10, 7, 12, 12, 128)       0                 time_distributed_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_13 (TimeDistributed)            (None, 10, 5, 10, 10, 64)        221248            time_distributed_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_14 (TimeDistributed)            (None, 10, 5, 10, 10, 64)        256               time_distributed_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# repeat_conv_3 (RepeatConv)                       (None, 10, 5, 10, 10, 32)        0                 activation_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_15 (TimeDistributed)            (None, 10, 5, 10, 10, 64)        0                 time_distributed_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_2 (Concatenate)                      (None, 10, 5, 10, 10, 96)        0                 repeat_conv_3[0][0]
#                                                                                                     time_distributed_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_16 (TimeDistributed)            (None, 10, 10, 20, 20, 96)       0                 concatenate_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_17 (TimeDistributed)            (None, 10, 12, 22, 22, 96)       0                 time_distributed_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_18 (TimeDistributed)            (None, 10, 10, 20, 20, 32)       82976             time_distributed_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_19 (TimeDistributed)            (None, 10, 10, 20, 20, 32)       128               time_distributed_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# repeat_conv_2 (RepeatConv)                       (None, 10, 10, 20, 20, 32)       0                 activation_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_20 (TimeDistributed)            (None, 10, 10, 20, 20, 32)       0                 time_distributed_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_3 (Concatenate)                      (None, 10, 10, 20, 20, 64)       0                 repeat_conv_2[0][0]
#                                                                                                     time_distributed_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_21 (TimeDistributed)            (None, 10, 10, 20, 20, 64)       0                 concatenate_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_22 (TimeDistributed)            (None, 10, 12, 22, 22, 64)       0                 time_distributed_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_23 (TimeDistributed)            (None, 10, 10, 20, 20, 32)       55328             time_distributed_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_24 (TimeDistributed)            (None, 10, 10, 20, 20, 32)       128               time_distributed_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# repeat_conv_1 (RepeatConv)                       (None, 10, 10, 20, 20, 16)       0                 activation_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_25 (TimeDistributed)            (None, 10, 10, 20, 20, 32)       0                 time_distributed_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_4 (Concatenate)                      (None, 10, 10, 20, 20, 48)       0                 repeat_conv_1[0][0]
#                                                                                                     time_distributed_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_26 (TimeDistributed)            (None, 10, 20, 40, 40, 48)       0                 concatenate_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_27 (TimeDistributed)            (None, 10, 22, 42, 42, 48)       0                 time_distributed_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_28 (TimeDistributed)            (None, 10, 20, 40, 40, 16)       20752             time_distributed_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_29 (TimeDistributed)            (None, 10, 20, 40, 40, 16)       64                time_distributed_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_30 (TimeDistributed)            (None, 10, 20, 40, 40, 16)       0                 time_distributed_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# time_distributed_31 (TimeDistributed)            (None, 10, 20, 40, 40, 1)        433               time_distributed_30[0][0]
# ======================================================================================================================================================
# Total params: 1,808,305
# Trainable params: 1,807,217
# Non-trainable params: 1,088
# ______________________________________________________________________________________________________________________________________________________

# %%
output_dir = 'saved_models/'
epochs = 500
train_nr = train_x.shape[0]
test_nr = 10
batch_size = 4
num_batch = int(train_nr/batch_size)

# %%
def vae_loss(x, t_decoded):
    '''Total loss for the plain UAE'''
    return K.mean(reconstruction_loss(x, t_decoded))


def reconstruction_loss(x, t_decoded):
    '''Reconstruction loss for the plain UAE'''

    return K.sum((K.batch_flatten(x) - K.batch_flatten(t_decoded)) ** 2, axis=-1)

def hard_data_loss(x, t_decoded):
    '''Compute Hard Data at Well Loc'''
    # prod 0——based [11,12],[41, 43],[10, 42],[42, 10]
    
    well_loc_x = [14, 4, 37, 36, 9, 21]
    well_loc_y = [31, 19, 3, 21, 4, 3]
    result = 0.
    for i in range(len(well_loc_x)):
        result = result + K.sum((K.batch_flatten(x[:, :, :, well_loc_y[i], well_loc_x[i], :]) - K.batch_flatten(t_decoded[:, :, :, well_loc_y[i], well_loc_x[i], :]))**2, axis = -1)
    return K.mean(result)

def joint_loss(x, t_decoded):
    return vae_loss(x, t_decoded) + 500 * hard_data_loss(x, t_decoded)

# %%
def relative_error(x, t_decoded):
    return K.mean(K.abs(x - t_decoded) / (x + 0.0001))

# %%
opt = Adam(lr=3e-4)
vae_model.compile(loss = joint_loss, optimizer = opt, metrics = [vae_loss, hard_data_loss, relative_error])
# Out:
# WARNING:tensorflow:From /data3/Astro/global/miniconda3/envs/cuda10.1-tf/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
lrScheduler = ReduceLROnPlateau(monitor = 'loss', factor = 0.5, patience = 10, cooldown = 1, verbose = 1, min_lr = 1e-7)
filePath = 'saved_models/saved-model-10steps-bs4-lr3e-4-pressure-detrend-hd-500-filter_16_32_32_64-mse-{epoch:03d}-{val_loss:.2f}.h5'
checkPoint = ModelCheckpoint(filePath, monitor = 'val_loss', verbose = 1, save_best_only = False, \
                             save_weights_only = True, mode = 'auto', period = 20)

callbacks_list = [lrScheduler, checkPoint]

# %%
history = vae_model.fit(train_x, train_y, batch_size = batch_size, epochs = epochs, \
                        verbose = 1, validation_data = (test_x, test_y), callbacks = callbacks_list)
